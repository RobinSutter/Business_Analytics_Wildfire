# %% [markdown]
# # Data Preparation - US Temperature Data
#
# This notebook filters the GlobalLandTemperaturesByCity dataset to extract only United States data.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import os

# %% [markdown]
# ## Load Global Temperature Data

# %%
# Load the global temperature data
data_path = '../../data/processed/GlobalLandTemperaturesByCity.csv'
df = pd.read_csv(data_path)

print(f"Total records: {len(df):,}")
print(f"Columns: {df.columns.tolist()}")
df.head()
# Out:
# Total records: 8,599,212
# Columns: ['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'City', 'Country', 'Latitude', 'Longitude']
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %% [markdown]
# ## Filter for United States Data

# %%
# Filter for United States data
us_df = df[df['Country'] == 'United States'].copy()

print(f"US records: {len(us_df):,}")
print(f"Unique US cities: {us_df['City'].nunique()}")
us_df.head()
# Out:
# US records: 687,289
# Unique US cities: 248
#                dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 47555  1820-01-01               2.101                          3.217  Abilene
# 47556  1820-02-01               6.926                          2.853  Abilene
# 47557  1820-03-01              10.767                          2.395  Abilene
# 47558  1820-04-01              17.989                          2.202  Abilene
# 47559  1820-05-01              21.809                          2.036  Abilene
#
#              Country Latitude Longitude
# 47555  United States   32.95N   100.53W
# 47556  United States   32.95N   100.53W
# 47557  United States   32.95N   100.53W
# 47558  United States   32.95N   100.53W
# 47559  United States   32.95N   100.53W

# %% [markdown]
# ## Save US Temperature Data

# %%
# Create output directory
output_dir = '../../data/processed/USTemperaturesByCity'
os.makedirs(output_dir, exist_ok=True)

# Save the US data
output_path = os.path.join(output_dir, 'USTemperaturesByCity.csv')
us_df.to_csv(output_path, index=False)

print(f"✓ US temperature data saved to: {output_path}")
print(f"✓ Total records saved: {len(us_df):,}")
# Out:
# ✓ US temperature data saved to: ../../data/processed/USTemperaturesByCity/USTemperaturesByCity.csv
# ✓ Total records saved: 687,289

# %%
# Check the most recent date in the US temperature data
us_df['dt'] = pd.to_datetime(us_df['dt'])
most_recent_date = us_df['dt'].max()
print(f"Most recent date in US temperature data: {most_recent_date}")

# Show the most recent records
print("\nMost recent records:")
us_df[us_df['dt'] == most_recent_date].sort_values('City')
# Out:
# Most recent date in US temperature data: 2013-09-01 00:00:00
#
# Most recent records:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 49879   2013-09-01              25.791                          1.180
# 140304  2013-09-01              17.799                          1.093
# 170399  2013-09-01              19.207                          0.866
# 190766  2013-09-01              19.643                          1.050
# 205489  2013-09-01              17.408                          1.048
# ...            ...                 ...                            ...
# 8215682 2013-09-01              26.466                          1.264
# 8224041 2013-09-01              17.503                          1.130
# 8230221 2013-09-01              21.692                          0.913
# 8255490 2013-09-01              15.883                          1.368
# 8439246 2013-09-01              17.408                          1.048
#
#                   City        Country Latitude Longitude
# 49879          Abilene  United States   32.95N   100.53W
# 140304           Akron  United States   40.99N    80.95W
# 170399     Albuquerque  United States   34.56N   107.03W
# 190766      Alexandria  United States   39.38N    76.99W
# 205489       Allentown  United States   40.99N    74.56W
# ...                ...            ...      ...       ...
# 8215682  Wichita Falls  United States   34.56N    99.24W
# 8224041        Windsor  United States   42.59N    82.91W
# 8230221  Winston Salem  United States   36.17N    79.56W
# 8255490      Worcester  United States   42.59N    72.00W
# 8439246        Yonkers  United States   40.99N    74.56W
#
# [257 rows x 7 columns]
